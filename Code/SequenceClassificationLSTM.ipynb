# %%
import numpy as np
import numpy.random as rd
import math
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
from google.colab import files
from keras.utils import to_categorical
from tensorflow.keras.applications import MobileNetV3Small

from tensorflow.keras.layers import Input, Dense, Activation,Lambda,Flatten,Dropout,LSTM,TimeDistributed,SimpleRNN
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.models import Sequential

# %%
x_train = []
y_train = []

# %%
for a in range(0,100):
  x1 = rd.rand(600)*10
  x2 = rd.rand(600)*10
  x3 = rd.rand(600)*10
  x4 = rd.rand(600)*10
  xcosx = np.array([0.1 * math.cos(i) * i + rd.rand() * 0.2 for i in x1])
  justx = np.array([0.1 * i  + rd.rand() * 0.2 for i in x2])
  sinx =  np.array([0.1 * math.sin(i) * 10+ rd.rand() * 0.2 for i in x3])
  logx = np.array([0.1 * math.log(i)  + rd.rand() * 0.2 for i in x4])
  x_train.append(xcosx)
  x_train.append(sinx)
  x_train.append(logx)
  x_train.append(justx)
  y_train.append(0)
  y_train.append(1)
  y_train.append(2)
  y_train.append(3)
  if a == 50:
    plt.scatter(x1[::1], xcosx[::1], s=2)
    plt.grid()
    plt.scatter(x2[::1], justx[::1], s=2)
    plt.grid()
    plt.scatter(x3[::1], sinx[::1], s=2)
    plt.grid()
    plt.scatter(x4[::1], logx[::1], s=2)
    plt.grid()
    plt.title("Données à modéliser")
    plt.show()

# %%
print(np.shape(x_train))
print(np.shape(y_train))
# Out:
# (400, 600)
# (400,)

# %%
# CNN
dense = Sequential()
dense.add(Dense(64, activation="relu", input_dim=1))
dense.add(Dense(64, activation="relu"))
dense.add(Dense(1, activation="linear"))

dense.compile(loss="mse", optimizer="adam")
dense.summary()

# LSTM
model = Sequential()
model.add(TimeDistributed(dense, input_shape=(600,1)))  # Adjust input_shape as needed
model.add(TimeDistributed(Flatten()))
model.add(LSTM(64))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(4, activation='softmax'))

# Compile the model with appropriate loss function for classification
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Now, you can print the summary of your model
model.summary()

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_crossentropy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                128
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4353 (17.00 KB)
# Trainable params: 4353 (17.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 600, 1)            4353
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 600, 1)            0
#  stributed)
#
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 27621 (107.89 KB)
# Trainable params: 27621 (107.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 600, 1)            4353
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 600, 1)            0
#  stributed)
#
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 27621 (107.89 KB)
# Trainable params: 27621 (107.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Combine x_train and y_train into a single list of tuples
data = list(zip(x_train, y_train))

# Shuffle the data
rd.shuffle(data)

# Unzip the shuffled data back into x_train and y_train
x_train_shuffled, y_train_shuffled = zip(*data)


x_train = np.array(x_train)
y_train = np.array(y_train)

y_train = to_categorical(y_train)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=18)

# Check the lengths to verify the split
print("Length of x_train:", len(x_train))
print("Length of x_test:", len(x_test))
print("Length of y_train:", len(y_train))
print("Length of y_test:", len(y_test))
# Out:
# Length of x_train: 320
# Length of x_test: 80
# Length of y_train: 320
# Length of y_test: 80

# %%
# CNN
dense = Sequential()
dense.add(Dense(64, activation="relu", input_dim=1))
dense.add(Dense(64, activation="relu"))
dense.add(Dense(1, activation="linear"))

dense.compile(loss="mse", optimizer="adam")
dense.summary()

# LSTM
model = Sequential()
model.add(TimeDistributed(dense, input_shape=(600,1)))  # Adjust input_shape as needed
model.add(TimeDistributed(Flatten()))
model.add(LSTM(64))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(4, activation='softmax'))

# Compile the model with appropriate loss function for classification
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Now, you can print the summary of your model
model.summary()

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_crossentropy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                128
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4353 (17.00 KB)
# Trainable params: 4353 (17.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 600, 1)            4353
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 600, 1)            0
#  stributed)
#
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 27621 (107.89 KB)
# Trainable params: 27621 (107.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 600, 1)            4353
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 600, 1)            0
#  stributed)
#
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 27621 (107.89 KB)
# Trainable params: 27621 (107.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print('---------TRAINING---------')
history = model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# ---------TRAINING---------
# Epoch 1/200
# 10/10 [==============================] - 7s 311ms/step - loss: 1.3861 - categorical_crossentropy: 1.3861
# Epoch 2/200
# 10/10 [==============================] - 3s 304ms/step - loss: 1.3856 - categorical_crossentropy: 1.3856
# Epoch 3/200
# 10/10 [==============================] - 3s 345ms/step - loss: 1.3850 - categorical_crossentropy: 1.3850
# Epoch 4/200
# 10/10 [==============================] - 3s 305ms/step - loss: 1.3841 - categorical_crossentropy: 1.3841
# Epoch 5/200
# 10/10 [==============================] - 3s 288ms/step - loss: 1.3829 - categorical_crossentropy: 1.3829
# Epoch 6/200
# 10/10 [==============================] - 2s 166ms/step - loss: 1.3811 - categorical_crossentropy: 1.3811
# Epoch 7/200
# 10/10 [==============================] - 2s 170ms/step - loss: 1.3784 - categorical_crossentropy: 1.3784
# Epoch 8/200
# 10/10 [==============================] - 2s 168ms/step - loss: 1.3746 - categorical_crossentropy: 1.3746
# Epoch 9/200
# 10/10 [==============================] - 2s 168ms/step - loss: 1.3687 - categorical_crossentropy: 1.3687
# Epoch 10/200
# 10/10 [==============================] - 2s 167ms/step - loss: 1.3587 - categorical_crossentropy: 1.3587
# Epoch 11/200
# 10/10 [==============================] - 2s 194ms/step - loss: 1.3394 - categorical_crossentropy: 1.3394
# Epoch 12/200
# 10/10 [==============================] - 2s 174ms/step - loss: 1.2862 - categorical_crossentropy: 1.2862
# Epoch 13/200
# 10/10 [==============================] - 2s 165ms/step - loss: 1.1553 - categorical_crossentropy: 1.1553
# Epoch 14/200
# 10/10 [==============================] - 2s 169ms/step - loss: 1.0914 - categorical_crossentropy: 1.0914
# Epoch 15/200
# 10/10 [==============================] - 2s 168ms/step - loss: 1.0616 - categorical_crossentropy: 1.0616
# Epoch 16/200
# 10/10 [==============================] - 2s 167ms/step - loss: 1.0367 - categorical_crossentropy: 1.0367
# Epoch 17/200
# 10/10 [==============================] - 2s 165ms/step - loss: 1.0254 - categorical_crossentropy: 1.0254
# Epoch 18/200
# 10/10 [==============================] - 2s 215ms/step - loss: 1.0150 - categorical_crossentropy: 1.0150
# Epoch 19/200
# 10/10 [==============================] - 2s 168ms/step - loss: 1.0049 - categorical_crossentropy: 1.0049
# Epoch 20/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.9933 - categorical_crossentropy: 0.9933
# Epoch 21/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.9795 - categorical_crossentropy: 0.9795
# Epoch 22/200
# 10/10 [==============================] - 2s 169ms/step - loss: 1.0737 - categorical_crossentropy: 1.0737
# Epoch 23/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.9957 - categorical_crossentropy: 0.9957
# Epoch 24/200
# 10/10 [==============================] - 2s 191ms/step - loss: 1.0255 - categorical_crossentropy: 1.0255
# Epoch 25/200
# 10/10 [==============================] - 2s 182ms/step - loss: 0.9788 - categorical_crossentropy: 0.9788
# Epoch 26/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.9598 - categorical_crossentropy: 0.9598
# Epoch 27/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.9371 - categorical_crossentropy: 0.9371
# Epoch 28/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.9221 - categorical_crossentropy: 0.9221
# Epoch 29/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.9074 - categorical_crossentropy: 0.9074
# Epoch 30/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.8962 - categorical_crossentropy: 0.8962
# Epoch 31/200
# 10/10 [==============================] - 2s 210ms/step - loss: 0.8823 - categorical_crossentropy: 0.8823
# Epoch 32/200
# 10/10 [==============================] - 2s 172ms/step - loss: 0.8693 - categorical_crossentropy: 0.8693
# Epoch 33/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.8705 - categorical_crossentropy: 0.8705
# Epoch 34/200
# 10/10 [==============================] - 2s 163ms/step - loss: 0.8574 - categorical_crossentropy: 0.8574
# Epoch 35/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.8881 - categorical_crossentropy: 0.8881
# Epoch 36/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.9007 - categorical_crossentropy: 0.9007
# Epoch 37/200
# 10/10 [==============================] - 2s 212ms/step - loss: 0.9561 - categorical_crossentropy: 0.9561
# Epoch 38/200
# 10/10 [==============================] - 2s 223ms/step - loss: 0.9230 - categorical_crossentropy: 0.9230
# Epoch 39/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.8635 - categorical_crossentropy: 0.8635
# Epoch 40/200
# 10/10 [==============================] - 2s 198ms/step - loss: 0.8002 - categorical_crossentropy: 0.8002
# Epoch 41/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.7820 - categorical_crossentropy: 0.7820
# Epoch 42/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.7591 - categorical_crossentropy: 0.7591
# Epoch 43/200
# 10/10 [==============================] - 2s 183ms/step - loss: 0.7384 - categorical_crossentropy: 0.7384
# Epoch 44/200
# 10/10 [==============================] - 2s 179ms/step - loss: 0.7260 - categorical_crossentropy: 0.7260
# Epoch 45/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.7022 - categorical_crossentropy: 0.7022
# Epoch 46/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.6834 - categorical_crossentropy: 0.6834
# Epoch 47/200
# 10/10 [==============================] - 2s 165ms/step - loss: 0.6704 - categorical_crossentropy: 0.6704
# Epoch 48/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.6457 - categorical_crossentropy: 0.6457
# Epoch 49/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.6226 - categorical_crossentropy: 0.6226
# Epoch 50/200
# 10/10 [==============================] - 2s 211ms/step - loss: 0.5997 - categorical_crossentropy: 0.5997
# Epoch 51/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.5662 - categorical_crossentropy: 0.5662
# Epoch 52/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.5389 - categorical_crossentropy: 0.5389
# Epoch 53/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.5127 - categorical_crossentropy: 0.5127
# Epoch 54/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.7211 - categorical_crossentropy: 0.7211
# Epoch 55/200
# 10/10 [==============================] - 2s 162ms/step - loss: 0.6676 - categorical_crossentropy: 0.6676
# Epoch 56/200
# 10/10 [==============================] - 2s 174ms/step - loss: 0.6393 - categorical_crossentropy: 0.6393
# Epoch 57/200
# 10/10 [==============================] - 2s 197ms/step - loss: 0.6096 - categorical_crossentropy: 0.6096
# Epoch 58/200
# 10/10 [==============================] - 2s 163ms/step - loss: 0.5592 - categorical_crossentropy: 0.5592
# Epoch 59/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.5793 - categorical_crossentropy: 0.5793
# Epoch 60/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.6757 - categorical_crossentropy: 0.6757
# Epoch 61/200
# 10/10 [==============================] - 2s 162ms/step - loss: 0.6174 - categorical_crossentropy: 0.6174
# Epoch 62/200
# 10/10 [==============================] - 2s 165ms/step - loss: 0.4930 - categorical_crossentropy: 0.4930
# Epoch 63/200
# 10/10 [==============================] - 2s 207ms/step - loss: 0.4556 - categorical_crossentropy: 0.4556
# Epoch 64/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.4279 - categorical_crossentropy: 0.4279
# Epoch 65/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.4148 - categorical_crossentropy: 0.4148
# Epoch 66/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.4008 - categorical_crossentropy: 0.4008
# Epoch 67/200
# 10/10 [==============================] - 2s 163ms/step - loss: 0.3854 - categorical_crossentropy: 0.3854
# Epoch 68/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.3713 - categorical_crossentropy: 0.3713
# Epoch 69/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.3629 - categorical_crossentropy: 0.3629
# Epoch 70/200
# 10/10 [==============================] - 2s 206ms/step - loss: 0.7372 - categorical_crossentropy: 0.7372
# Epoch 71/200
# 10/10 [==============================] - 2s 163ms/step - loss: 0.6225 - categorical_crossentropy: 0.6225
# Epoch 72/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.5732 - categorical_crossentropy: 0.5732
# Epoch 73/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.5686 - categorical_crossentropy: 0.5686
# Epoch 74/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.5605 - categorical_crossentropy: 0.5605
# Epoch 75/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.5492 - categorical_crossentropy: 0.5492
# Epoch 76/200
# 10/10 [==============================] - 2s 202ms/step - loss: 0.5370 - categorical_crossentropy: 0.5370
# Epoch 77/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.5208 - categorical_crossentropy: 0.5208
# Epoch 78/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.4307 - categorical_crossentropy: 0.4307
# Epoch 79/200
# 10/10 [==============================] - 2s 165ms/step - loss: 0.3577 - categorical_crossentropy: 0.3577
# Epoch 80/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3055 - categorical_crossentropy: 0.3055
# Epoch 81/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.3063 - categorical_crossentropy: 0.3063
# Epoch 82/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.2656 - categorical_crossentropy: 0.2656
# Epoch 83/200
# 10/10 [==============================] - 2s 202ms/step - loss: 0.2446 - categorical_crossentropy: 0.2446
# Epoch 84/200
# 10/10 [==============================] - 2s 163ms/step - loss: 0.2205 - categorical_crossentropy: 0.2205
# Epoch 85/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.2033 - categorical_crossentropy: 0.2033
# Epoch 86/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.1951 - categorical_crossentropy: 0.1951
# Epoch 87/200
# 10/10 [==============================] - 2s 175ms/step - loss: 0.1712 - categorical_crossentropy: 0.1712
# Epoch 88/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.1610 - categorical_crossentropy: 0.1610
# Epoch 89/200
# 10/10 [==============================] - 2s 197ms/step - loss: 0.1853 - categorical_crossentropy: 0.1853
# Epoch 90/200
# 10/10 [==============================] - 2s 174ms/step - loss: 0.6688 - categorical_crossentropy: 0.6688
# Epoch 91/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.5419 - categorical_crossentropy: 0.5419
# Epoch 92/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.4096 - categorical_crossentropy: 0.4096
# Epoch 93/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.4196 - categorical_crossentropy: 0.4196
# Epoch 94/200
# 10/10 [==============================] - 2s 168ms/step - loss: 2.6088 - categorical_crossentropy: 2.6088
# Epoch 95/200
# 10/10 [==============================] - 2s 165ms/step - loss: 2.7657 - categorical_crossentropy: 2.7657
# Epoch 96/200
# 10/10 [==============================] - 2s 208ms/step - loss: 1.6076 - categorical_crossentropy: 1.6076
# Epoch 97/200
# 10/10 [==============================] - 2s 172ms/step - loss: 1.0620 - categorical_crossentropy: 1.0620
# Epoch 98/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.5319 - categorical_crossentropy: 0.5319
# Epoch 99/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.5192 - categorical_crossentropy: 0.5192
# Epoch 100/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.4957 - categorical_crossentropy: 0.4957
# Epoch 101/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.4781 - categorical_crossentropy: 0.4781
# Epoch 102/200
# 10/10 [==============================] - 2s 196ms/step - loss: 0.4658 - categorical_crossentropy: 0.4658
# Epoch 103/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.4554 - categorical_crossentropy: 0.4554
# Epoch 104/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.4439 - categorical_crossentropy: 0.4439
# Epoch 105/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.4339 - categorical_crossentropy: 0.4339
# Epoch 106/200
# 10/10 [==============================] - 2s 174ms/step - loss: 0.4241 - categorical_crossentropy: 0.4241
# Epoch 107/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.4163 - categorical_crossentropy: 0.4163
# Epoch 108/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.4086 - categorical_crossentropy: 0.4086
# Epoch 109/200
# 10/10 [==============================] - 2s 205ms/step - loss: 0.4023 - categorical_crossentropy: 0.4023
# Epoch 110/200
# 10/10 [==============================] - 2s 160ms/step - loss: 0.3962 - categorical_crossentropy: 0.3962
# Epoch 111/200
# 10/10 [==============================] - 2s 165ms/step - loss: 0.3908 - categorical_crossentropy: 0.3908
# Epoch 112/200
# 10/10 [==============================] - 2s 163ms/step - loss: 0.3859 - categorical_crossentropy: 0.3859
# Epoch 113/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.3826 - categorical_crossentropy: 0.3826
# Epoch 114/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3770 - categorical_crossentropy: 0.3770
# Epoch 115/200
# 10/10 [==============================] - 2s 197ms/step - loss: 0.3735 - categorical_crossentropy: 0.3735
# Epoch 116/200
# 10/10 [==============================] - 2s 178ms/step - loss: 0.3694 - categorical_crossentropy: 0.3694
# Epoch 117/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.3659 - categorical_crossentropy: 0.3659
# Epoch 118/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.3623 - categorical_crossentropy: 0.3623
# Epoch 119/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3589 - categorical_crossentropy: 0.3589
# Epoch 120/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3552 - categorical_crossentropy: 0.3552
# Epoch 121/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.3520 - categorical_crossentropy: 0.3520
# Epoch 122/200
# 10/10 [==============================] - 2s 213ms/step - loss: 0.3605 - categorical_crossentropy: 0.3605
# Epoch 123/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.3466 - categorical_crossentropy: 0.3466
# Epoch 124/200
# 10/10 [==============================] - 2s 163ms/step - loss: 0.3427 - categorical_crossentropy: 0.3427
# Epoch 125/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.3394 - categorical_crossentropy: 0.3394
# Epoch 126/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.3490 - categorical_crossentropy: 0.3490
# Epoch 127/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3330 - categorical_crossentropy: 0.3330
# Epoch 128/200
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3870 - categorical_crossentropy: 0.3870
# Epoch 129/200
# 10/10 [==============================] - 2s 178ms/step - loss: 0.6192 - categorical_crossentropy: 0.6192
# Epoch 130/200
# 10/10 [==============================] - 2s 169ms/step - loss: 1.0330 - categorical_crossentropy: 1.0330
# Epoch 131/200
# 10/10 [==============================] - 2s 169ms/step - loss: 1.0798 - categorical_crossentropy: 1.0798
# Epoch 132/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.9526 - categorical_crossentropy: 0.9526
# Epoch 133/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.8835 - categorical_crossentropy: 0.8835
# Epoch 134/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.8198 - categorical_crossentropy: 0.8198
# Epoch 135/200
# 10/10 [==============================] - 2s 208ms/step - loss: 0.7642 - categorical_crossentropy: 0.7642
# Epoch 136/200
# 10/10 [==============================] - 2s 165ms/step - loss: 0.7286 - categorical_crossentropy: 0.7286
# Epoch 137/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.6993 - categorical_crossentropy: 0.6993
# Epoch 138/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.6729 - categorical_crossentropy: 0.6729
# Epoch 139/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.6474 - categorical_crossentropy: 0.6474
# Epoch 140/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.6253 - categorical_crossentropy: 0.6253
# Epoch 141/200
# 10/10 [==============================] - 2s 188ms/step - loss: 0.6049 - categorical_crossentropy: 0.6049
# Epoch 142/200
# 10/10 [==============================] - 2s 181ms/step - loss: 0.5858 - categorical_crossentropy: 0.5858
# Epoch 143/200
# 10/10 [==============================] - 2s 163ms/step - loss: 0.5670 - categorical_crossentropy: 0.5670
# Epoch 144/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.5493 - categorical_crossentropy: 0.5493
# Epoch 145/200
# 10/10 [==============================] - 2s 173ms/step - loss: 0.5316 - categorical_crossentropy: 0.5316
# Epoch 146/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.5149 - categorical_crossentropy: 0.5149
# Epoch 147/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.4990 - categorical_crossentropy: 0.4990
# Epoch 148/200
# 10/10 [==============================] - 2s 209ms/step - loss: 0.4848 - categorical_crossentropy: 0.4848
# Epoch 149/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.4707 - categorical_crossentropy: 0.4707
# Epoch 150/200
# 10/10 [==============================] - 2s 172ms/step - loss: 0.4579 - categorical_crossentropy: 0.4579
# Epoch 151/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.4468 - categorical_crossentropy: 0.4468
# Epoch 152/200
# 10/10 [==============================] - 2s 173ms/step - loss: 0.4354 - categorical_crossentropy: 0.4354
# Epoch 153/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.4254 - categorical_crossentropy: 0.4254
# Epoch 154/200
# 10/10 [==============================] - 2s 187ms/step - loss: 0.4162 - categorical_crossentropy: 0.4162
# Epoch 155/200
# 10/10 [==============================] - 2s 180ms/step - loss: 0.4075 - categorical_crossentropy: 0.4075
# Epoch 156/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.3996 - categorical_crossentropy: 0.3996
# Epoch 157/200
# 10/10 [==============================] - 2s 175ms/step - loss: 0.3926 - categorical_crossentropy: 0.3926
# Epoch 158/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.3864 - categorical_crossentropy: 0.3864
# Epoch 159/200
# 10/10 [==============================] - 2s 173ms/step - loss: 0.3807 - categorical_crossentropy: 0.3807
# Epoch 160/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.3754 - categorical_crossentropy: 0.3754
# Epoch 161/200
# 10/10 [==============================] - 2s 210ms/step - loss: 0.3661 - categorical_crossentropy: 0.3661
# Epoch 162/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.3613 - categorical_crossentropy: 0.3613
# Epoch 163/200
# 10/10 [==============================] - 2s 172ms/step - loss: 0.3566 - categorical_crossentropy: 0.3566
# Epoch 164/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.3523 - categorical_crossentropy: 0.3523
# Epoch 165/200
# 10/10 [==============================] - 2s 172ms/step - loss: 0.3480 - categorical_crossentropy: 0.3480
# Epoch 166/200
# 10/10 [==============================] - 2s 172ms/step - loss: 0.3438 - categorical_crossentropy: 0.3438
# Epoch 167/200
# 10/10 [==============================] - 2s 206ms/step - loss: 0.3396 - categorical_crossentropy: 0.3396
# Epoch 168/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3355 - categorical_crossentropy: 0.3355
# Epoch 169/200
# 10/10 [==============================] - 2s 173ms/step - loss: 0.3315 - categorical_crossentropy: 0.3315
# Epoch 170/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.3276 - categorical_crossentropy: 0.3276
# Epoch 171/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3240 - categorical_crossentropy: 0.3240
# Epoch 172/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.3200 - categorical_crossentropy: 0.3200
# Epoch 173/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.3164 - categorical_crossentropy: 0.3164
# Epoch 174/200
# 10/10 [==============================] - 2s 202ms/step - loss: 0.3123 - categorical_crossentropy: 0.3123
# Epoch 175/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.3143 - categorical_crossentropy: 0.3143
# Epoch 176/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3106 - categorical_crossentropy: 0.3106
# Epoch 177/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.3012 - categorical_crossentropy: 0.3012
# Epoch 178/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.2974 - categorical_crossentropy: 0.2974
# Epoch 179/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.2934 - categorical_crossentropy: 0.2934
# Epoch 180/200
# 10/10 [==============================] - 2s 203ms/step - loss: 0.2945 - categorical_crossentropy: 0.2945
# Epoch 181/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.2907 - categorical_crossentropy: 0.2907
# Epoch 182/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.2860 - categorical_crossentropy: 0.2860
# Epoch 183/200
# 10/10 [==============================] - 2s 162ms/step - loss: 0.2768 - categorical_crossentropy: 0.2768
# Epoch 184/200
# 10/10 [==============================] - 2s 164ms/step - loss: 0.2770 - categorical_crossentropy: 0.2770
# Epoch 185/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.2722 - categorical_crossentropy: 0.2722
# Epoch 186/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.2672 - categorical_crossentropy: 0.2672
# Epoch 187/200
# 10/10 [==============================] - 2s 252ms/step - loss: 0.2622 - categorical_crossentropy: 0.2622
# Epoch 188/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.2568 - categorical_crossentropy: 0.2568
# Epoch 189/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.2516 - categorical_crossentropy: 0.2516
# Epoch 190/200
# 10/10 [==============================] - 2s 166ms/step - loss: 0.2439 - categorical_crossentropy: 0.2439
# Epoch 191/200
# 10/10 [==============================] - 2s 165ms/step - loss: 0.2411 - categorical_crossentropy: 0.2411
# Epoch 192/200
# 10/10 [==============================] - 2s 163ms/step - loss: 0.2484 - categorical_crossentropy: 0.2484
# Epoch 193/200
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2329 - categorical_crossentropy: 0.2329
# Epoch 194/200
# 10/10 [==============================] - 2s 185ms/step - loss: 0.2280 - categorical_crossentropy: 0.2280
# Epoch 195/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.2226 - categorical_crossentropy: 0.2226
# Epoch 196/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.2173 - categorical_crossentropy: 0.2173
# Epoch 197/200
# 10/10 [==============================] - 2s 165ms/step - loss: 0.2119 - categorical_crossentropy: 0.2119
# Epoch 198/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.2073 - categorical_crossentropy: 0.2073
# Epoch 199/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.2022 - categorical_crossentropy: 0.2022
# Epoch 200/200
# 10/10 [==============================] - 2s 212ms/step - loss: 0.1968 - categorical_crossentropy: 0.1968

# %%
print('---------EVALUATION---------')
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')


# Plot MAE for training and validation
plt.plot(history.history['categorical_crossentropy'], label='Training')
plt.xlabel('Epochs')
plt.ylabel('Performance')
plt.legend()
plt.show()



predicted_classes = np.argmax(model.predict(x_test), axis=-1)
print(predicted_classes)
y = np.argmax(y_test,axis=1)
print(y)

incorrects = np.nonzero(predicted_classes != y)[0]
print(f"Pourcentage d'erreur: {(incorrects.size/y.size)*100}%")
# Out:
# ---------EVALUATION---------
# 3/3 [==============================] - 1s 41ms/step - loss: 0.1963 - categorical_crossentropy: 0.1963
# Test Loss: 0.1963474005460739
# Test Accuracy: 0.1963474005460739
# 3/3 [==============================] - 1s 48ms/step
# [1 2 0 1 0 2 2 2 2 3 2 1 3 1 1 3 2 2 3 2 3 0 0 2 2 2 1 1 2 1 3 1 3 0 0 3 0
#  3 0 1 0 1 3 3 0 3 3 3 3 1 0 2 2 0 1 0 0 3 1 3 1 1 2 0 1 2 0 2 1 1 2 1 1 1
#  3 1 3 1 2 2]
# [1 2 0 1 0 0 2 2 2 3 2 1 3 1 1 3 2 2 3 2 3 0 0 2 2 2 1 1 2 1 3 1 3 0 0 3 0
#  3 0 1 0 1 3 3 0 3 3 3 3 1 0 2 2 0 1 0 0 3 1 3 1 1 2 0 1 2 0 2 1 1 2 1 1 1
#  3 1 3 1 2 2]
# Pourcentage d'erreur: 1.25%
